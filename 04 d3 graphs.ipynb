# %% [markdown]
# # Imports

# %%
import py_d3
# %reload_ext py_d3

# %% [markdown]
# # Repaso

# %% [markdown]
# ## Interactuar con Javascript
# Y sacar el output por la consola :D

# %%
# %%d3
#
# <script>
#     console.log("Hello there!")
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select52 = function(selection) {
#     return _select("#d3-cell-52").select(selection);
# }
# d3.selectAll52 = function(selection) {
#     return _select("#d3-cell-52").selectAll(selection);
# }
# </script>
# <g id="d3-cell-52">
#
# <script>
#     console.log("Hello there!")
# </script>
# </g>

# %% [markdown]
# # Agregar texto

# %%
# %%d3
#
# <g />
#
# <script>
#     d3.select("g")
#         .append("p")
#         .text("hi")
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select50 = function(selection) {
#     return _select("#d3-cell-50").select(selection);
# }
# d3.selectAll50 = function(selection) {
#     return _select("#d3-cell-50").selectAll(selection);
# }
# </script>
# <g id="d3-cell-50">
#
# <g />
# <script>
#
#     d3.select50("g")
#         .append("p")
#         .text("hi")
#
# </script>
# </g>

# %% [markdown]
# # Colorear el fondo
# Solo para ver el tamaño completo del canvas :)

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select46 = function(selection) {
#     return _select("#d3-cell-46").select(selection);
# }
# d3.selectAll46 = function(selection) {
#     return _select("#d3-cell-46").selectAll(selection);
# }
# </script>
# <g id="d3-cell-46">
#
# <svg width="100" height = "100" />
# <g />
# <script>
#
#     var svg = d3.select46("svg")
#         .attr("style","background: lightgray;");
# </script>
# </g>

# %% [markdown]
# # Agregar una cuadrado

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("rect")
#         .attr("width", "10px")
#         .attr("height", "10px")
#         .attr("x", 45)
#         .attr("y", 45)
#         .attr("fill", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select53 = function(selection) {
#     return _select("#d3-cell-53").select(selection);
# }
# d3.selectAll53 = function(selection) {
#     return _select("#d3-cell-53").selectAll(selection);
# }
# </script>
# <g id="d3-cell-53">
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select53("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("rect")
#         .attr("width", "10px")
#         .attr("height", "10px")
#         .attr("x", 45)
#         .attr("y", 45)
#         .attr("fill", "red");
#
# </script>
# </g>

# %% [markdown]
# # Agregar una circulo
# Esta vez el centro con `50%`

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("circle")
#         .attr("cx", "50%")
#         .attr("cy", "50%")
#         .attr("r", "10")
#         .attr("fill", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select49 = function(selection) {
#     return _select("#d3-cell-49").select(selection);
# }
# d3.selectAll49 = function(selection) {
#     return _select("#d3-cell-49").selectAll(selection);
# }
# </script>
# <g id="d3-cell-49">
#
# <svg width="100" height = "100" />
# <g />
# <script>
#
#     var svg = d3.select49("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("circle")
#         .attr("cx", "50%")
#         .attr("cy", "50%")
#         .attr("r", "10")
#         .attr("fill", "red");
#
# </script>
# </g>

# %% [markdown]
# # Agregar una línea

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("line")
#         .attr("x1", "10%")
#         .attr("y1", "10%")
#         .attr("x2", "90%")
#         .attr("y2", "90%")
#         .attr("stroke", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select57 = function(selection) {
#     return _select("#d3-cell-57").select(selection);
# }
# d3.selectAll57 = function(selection) {
#     return _select("#d3-cell-57").selectAll(selection);
# }
# </script>
# <g id="d3-cell-57">
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select57("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("line")
#         .attr("x1", "10%")
#         .attr("y1", "10%")
#         .attr("x2", "90%")
#         .attr("y2", "90%")
#         .attr("stroke", "red");
#
# </script>
# </g>

# %% [markdown]
# # Prototipo de Grafo

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("line")
#         .attr("x1", "50")
#         .attr("y1", "20")
#         .attr("x2", "20")
#         .attr("y2", "80")
#         .attr("stroke", "blue");
#
#     svg.append("line")
#         .attr("x1", "20")
#         .attr("y1", "80")
#         .attr("x2", "80")
#         .attr("y2", "80")
#         .attr("stroke", "blue");
#
#     svg.append("circle")
#         .attr("cx", "50")
#         .attr("cy", "20")
#         .attr("r", "10")
#         .attr("fill", "red");
#
#     svg.append("circle")
#         .attr("cx", "20")
#         .attr("cy", "80")
#         .attr("r", "10")
#         .attr("fill", "red");
#
#     svg.append("circle")
#         .attr("cx", "80")
#         .attr("cy", "80")
#         .attr("r", "10")
#         .attr("fill", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select91 = function(selection) {
#     return _select("#d3-cell-91").select(selection);
# }
# d3.selectAll91 = function(selection) {
#     return _select("#d3-cell-91").selectAll(selection);
# }
# </script>
# <g id="d3-cell-91">
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var svg = d3.select91("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("line")
#         .attr("x1", "50")
#         .attr("y1", "20")
#         .attr("x2", "20")
#         .attr("y2", "80")
#         .attr("stroke", "blue");
#
#     svg.append("line")
#         .attr("x1", "20")
#         .attr("y1", "80")
#         .attr("x2", "80")
#         .attr("y2", "80")
#         .attr("stroke", "blue");
#
#     svg.append("circle")
#         .attr("cx", "50")
#         .attr("cy", "20")
#         .attr("r", "10")
#         .attr("fill", "red");
#
#     svg.append("circle")
#         .attr("cx", "20")
#         .attr("cy", "80")
#         .attr("r", "10")
#         .attr("fill", "red");
#
#     svg.append("circle")
#         .attr("cx", "80")
#         .attr("cy", "80")
#         .attr("r", "10")
#         .attr("fill", "red");
#
#
#
# </script>
# </g>

# %% [markdown]
# # Estructuras de datos

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var dataset = [10, 10, 90, 90];
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("line")
#         .attr("x1", dataset[0])
#         .attr("y1", dataset[1])
#         .attr("x2", dataset[2])
#         .attr("y2", dataset[3])
#         .attr("stroke", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select59 = function(selection) {
#     return _select("#d3-cell-59").select(selection);
# }
# d3.selectAll59 = function(selection) {
#     return _select("#d3-cell-59").selectAll(selection);
# }
# </script>
# <g id="d3-cell-59">
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var dataset = [10, 10, 90, 90];
#
#     var svg = d3.select59("svg")
#         .attr("style","background: lightgray;");
#
#     svg.append("line")
#         .attr("x1", dataset[0])
#         .attr("y1", dataset[1])
#         .attr("x2", dataset[2])
#         .attr("y2", dataset[3])
#         .attr("stroke", "red");
#
# </script>
# </g>

# %% [markdown]
# # Funciones en datos

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var dataset = [[10, 10, 90, 90], [90, 10, 10, 90]];
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("line")
#         .data(dataset)
#         .enter()
#         .append("line")
#         .attr("x1", function(d,i) { return d[0]; })
#         .attr("y1", function(d,i) { return d[1]; })
#         .attr("x2", function(d,i) { return d[2]; })
#         .attr("y2", function(d,i) { return d[3]; })
#         .attr("stroke", "red");
#
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select74 = function(selection) {
#     return _select("#d3-cell-74").select(selection);
# }
# d3.selectAll74 = function(selection) {
#     return _select("#d3-cell-74").selectAll(selection);
# }
# </script>
# <g id="d3-cell-74">
#
# <svg width="100" height = "100" />
#
# <script>
#
#     var dataset = [[10, 10, 90, 90], [90, 10, 10, 90]];
#
#     var svg = d3.select74("svg")
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("line")
#         .data(dataset)
#         .enter()
#         .append("line")
#         .attr("x1", function(d,i) { return d[0]; })
#         .attr("y1", function(d,i) { return d[1]; })
#         .attr("x2", function(d,i) { return d[2]; })
#         .attr("y2", function(d,i) { return d[3]; })
#         .attr("stroke", "red");
#
#
# </script>
# </g>

# %% [markdown]
# # Generar datos

# %%
# %%d3
#
# <svg width="100" height = "100" />
#
# <script>
#     w = 100
#     h = 100
#
#     var dataset = []
#
#     for(var i = 0; i < 20; i++){
#         var x1 = Math.round(Math.random()*w);
#         var y1 = Math.round(Math.random()*h);
#         var x2 = Math.round(Math.random()*w);
#         var y2 = Math.round(Math.random()*h);
#         dataset.push([x1, y1, x2, y2]);
#     }
#
#     var svg = d3.select("svg")
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("line")
#         .data(dataset)
#         .enter()
#         .append("line")
#         .attr("x1", function(d,i) { return d[0]; })
#         .attr("y1", function(d,i) { return d[1]; })
#         .attr("x2", function(d,i) { return d[2]; })
#         .attr("y2", function(d,i) { return d[3]; })
#         .attr("stroke", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select94 = function(selection) {
#     return _select("#d3-cell-94").select(selection);
# }
# d3.selectAll94 = function(selection) {
#     return _select("#d3-cell-94").selectAll(selection);
# }
# </script>
# <g id="d3-cell-94">
#
# <svg width="100" height = "100" />
#
# <script>
#     w = 100
#     h = 100
#
#     var dataset = []
#
#     for(var i = 0; i < 20; i++){
#         var x1 = Math.round(Math.random()*w);
#         var y1 = Math.round(Math.random()*h);
#         var x2 = Math.round(Math.random()*w);
#         var y2 = Math.round(Math.random()*h);
#         dataset.push([x1, y1, x2, y2]);
#     }
#
#     var svg = d3.select94("svg")
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("line")
#         .data(dataset)
#         .enter()
#         .append("line")
#         .attr("x1", function(d,i) { return d[0]; })
#         .attr("y1", function(d,i) { return d[1]; })
#         .attr("x2", function(d,i) { return d[2]; })
#         .attr("y2", function(d,i) { return d[3]; })
#         .attr("stroke", "red");
#
#
# </script>
# </g>

# %% [markdown]
# # Prototipo de Grafo con valores aleatorios

# %%
# %%d3
#
# <svg/>
#
# <script>
#     w = 500
#     h = 500
#
#     var nodes = []
#
#     for(var i = 0; i < 20; i++){
#         var x1 = Math.round(Math.random()*w);
#         var y1 = Math.round(Math.random()*h);
#         nodes.push([x1, y1]);
#     }
#
#     var svg = d3.select("svg")
#         .attr("width", w)
#         .attr("height", h)
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("circle")
#         .data(nodes)
#         .enter()
#         .append("circle")
#         .attr("cx", function(d,i) { return d[0]; })
#         .attr("cy", function(d,i) { return d[1]; })
#         .attr("r", 10)
#         .attr("fill", "red");
#
#     for (var i = 0; i < nodes.length - 1; i++){
#         d3.select("svg")
#             .append("line")
#             .attr("x1", function(d) { return nodes[i][0]; })
#             .attr("y1", function(d) { return nodes[i][1]; })
#             .attr("x2", function(d) { return nodes[i+1][0]; })
#             .attr("y2", function(d) { return nodes[i+1][1]; })
#             .attr("stroke", "blue");
#     }
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select108 = function(selection) {
#     return _select("#d3-cell-108").select(selection);
# }
# d3.selectAll108 = function(selection) {
#     return _select("#d3-cell-108").selectAll(selection);
# }
# </script>
# <g id="d3-cell-108">
#
# <svg/>
#
# <script>
#     w = 500
#     h = 500
#
#     var nodes = []
#
#     for(var i = 0; i < 20; i++){
#         var x1 = Math.round(Math.random()*w);
#         var y1 = Math.round(Math.random()*h);
#         nodes.push([x1, y1]);
#     }
#
#     var svg = d3.select108("svg")
#         .attr("width", w)
#         .attr("height", h)
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("circle")
#         .data(nodes)
#         .enter()
#         .append("circle")
#         .attr("cx", function(d,i) { return d[0]; })
#         .attr("cy", function(d,i) { return d[1]; })
#         .attr("r", 10)
#         .attr("fill", "red");
#
#     for (var i = 0; i < nodes.length - 1; i++){
#         d3.select108("svg")
#             .append("line")
#             .attr("x1", function(d) { return nodes[i][0]; })
#             .attr("y1", function(d) { return nodes[i][1]; })
#             .attr("x2", function(d) { return nodes[i+1][0]; })
#             .attr("y2", function(d) { return nodes[i+1][1]; })
#             .attr("stroke", "blue");
#     }
#
# </script>
# </g>

# %% [markdown]
# # Nodos con diccionario {x: , y: }

# %%
# %%d3
#
# <svg/>
#
# <script>
#     w = 150
#     h = 150
#
#     var nodes = [
#         {x: 110, y: 20},
#         {x: 50, y: 80},
#         {x: 90, y: 120}
#     ]
#
#     var svg = d3.select("svg")
#         .attr("width", w)
#         .attr("height", h)
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("circle")
#         .data(nodes)
#         .enter()
#         .append("circle")
#         .attr("cx", function(d,i) { return d.x; })
#         .attr("cy", function(d,i) { return d.y; })
#         .attr("r", 10)
#         .attr("fill", "red");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select118 = function(selection) {
#     return _select("#d3-cell-118").select(selection);
# }
# d3.selectAll118 = function(selection) {
#     return _select("#d3-cell-118").selectAll(selection);
# }
# </script>
# <g id="d3-cell-118">
#
# <svg/>
#
# <script>
#     w = 150
#     h = 150
#
#     var nodes = [
#         {x: 110, y: 20},
#         {x: 50, y: 80},
#         {x: 90, y: 120}
#     ]
#
#     var svg = d3.select118("svg")
#         .attr("width", w)
#         .attr("height", h)
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("circle")
#         .data(nodes)
#         .enter()
#         .append("circle")
#         .attr("cx", function(d,i) { return d.x; })
#         .attr("cy", function(d,i) { return d.y; })
#         .attr("r", 10)
#         .attr("fill", "red");
#
# </script>
# </g>

# %% [markdown]
# # Vértices con diccionario {source: , target: }

# %%
# %%d3
#
# <svg/>
#
# <script>
#     w = 150
#     h = 150
#
#     var nodes = [
#         {x: 110, y: 20},
#         {x: 50, y: 80},
#         {x: 90, y: 120}
#     ]
#
#     var links = [
#         {source: nodes[0], target: nodes[1]},
#         {source: nodes[2], target: nodes[1]},
#         {source: nodes[0], target: nodes[2]},
#     ]
#
#     var svg = d3.select("svg")
#         .attr("width", w)
#         .attr("height", h)
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("circle")
#         .data(nodes)
#         .enter()
#         .append("circle")
#         .attr("cx", function(d,i) { return d.x; })
#         .attr("cy", function(d,i) { return d.y; })
#         .attr("r", 10)
#         .attr("fill", "red");
#
#     svg.selectAll("line")
#        .data(links)
#        .enter()
#        .append("line")
#        .attr("x1", function(d) { return d.source.x })
#        .attr("y1", function(d) { return d.source.y })
#        .attr("x2", function(d) { return d.target.x })
#        .attr("y2", function(d) { return d.target.y })
#        .style("stroke", "blue");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select119 = function(selection) {
#     return _select("#d3-cell-119").select(selection);
# }
# d3.selectAll119 = function(selection) {
#     return _select("#d3-cell-119").selectAll(selection);
# }
# </script>
# <g id="d3-cell-119">
#
# <svg/>
#
# <script>
#     w = 150
#     h = 150
#
#     var nodes = [
#         {x: 110, y: 20},
#         {x: 50, y: 80},
#         {x: 90, y: 120}
#     ]
#
#     var links = [
#         {source: nodes[0], target: nodes[1]},
#         {source: nodes[2], target: nodes[1]},
#         {source: nodes[0], target: nodes[2]},
#     ]
#
#     var svg = d3.select119("svg")
#         .attr("width", w)
#         .attr("height", h)
#         .attr("style","background: lightgray;");
#
#     svg.selectAll("circle")
#         .data(nodes)
#         .enter()
#         .append("circle")
#         .attr("cx", function(d,i) { return d.x; })
#         .attr("cy", function(d,i) { return d.y; })
#         .attr("r", 10)
#         .attr("fill", "red");
#
#     svg.selectAll("line")
#        .data(links)
#        .enter()
#        .append("line")
#        .attr("x1", function(d) { return d.source.x })
#        .attr("y1", function(d) { return d.source.y })
#        .attr("x2", function(d) { return d.target.x })
#        .attr("y2", function(d) { return d.target.y })
#        .style("stroke", "blue");
#
# </script>
# </g>
