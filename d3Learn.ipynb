# %%
import py_d3
# %reload_ext py_d3

# %%
# %%d3
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127
#         fill=red stroke=black stroke-width=4/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50
#         fill=blue stroke-width=4 stroke=black/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select14 = function(selection) {
#     return _select("#d3-cell-14").select(selection);
# }
# d3.selectAll14 = function(selection) {
#     return _select("#d3-cell-14").selectAll(selection);
# }
# </script>
# <g id="d3-cell-14">
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127
#         fill=red stroke=black stroke-width=4/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50
#         fill=blue stroke-width=4 stroke=black/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# </g>

# %%
# %%d3
#
# <style>
# svg .circle1 {
#     fill: red;
#     stroke: black;
#     stroke-width: 5;
# }
#
# svg .rect1 {
#     fill:blue;
#     stroke-width:4;
#     stroke:black;
# }
#
# </style>
#
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127 class="circle1"/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50 class="rect1"/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select15 = function(selection) {
#     return _select("#d3-cell-15").select(selection);
# }
# d3.selectAll15 = function(selection) {
#     return _select("#d3-cell-15").selectAll(selection);
# }
# </script>
# <g id="d3-cell-15">
# <style>
# svg .circle1 {
#     fill: red;
#     stroke: black;
#     stroke-width: 5;
# }
#
# svg .rect1 {
#     fill:blue;
#     stroke-width:4;
#     stroke:black;
# }
#
# </style>
#
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127 class="circle1"/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50 class="rect1"/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# </g>

# %%
# %%d3
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 1.0)"/>
#     <circle cx="50" cy="25" r="20" fill="rgba(0, 0, 255, 0.75)"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.5)"/>
#     <circle cx="100" cy="25" r="20" fill="rgba(255, 255, 0, 0.25)"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 0, 0, 0.1)"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select16 = function(selection) {
#     return _select("#d3-cell-16").select(selection);
# }
# d3.selectAll16 = function(selection) {
#     return _select("#d3-cell-16").selectAll(selection);
# }
# </script>
# <g id="d3-cell-16">
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 1.0)"/>
#     <circle cx="50" cy="25" r="20" fill="rgba(0, 0, 255, 0.75)"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.5)"/>
#     <circle cx="100" cy="25" r="20" fill="rgba(255, 255, 0, 0.25)"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 0, 0, 0.1)"/>
# </svg>
# </g>

# %%
# %%d3
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 0.75)" stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.75)" stroke="rgba(0, 0, 255, 0.25)" stroke-width="10"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 255, 0, 0.75)" stroke="rgba(255, 0, 0, 0.25)" stroke-width="10"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select17 = function(selection) {
#     return _select("#d3-cell-17").select(selection);
# }
# d3.selectAll17 = function(selection) {
#     return _select("#d3-cell-17").selectAll(selection);
# }
# </script>
# <g id="d3-cell-17">
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 0.75)" stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.75)" stroke="rgba(0, 0, 255, 0.25)" stroke-width="10"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 255, 0, 0.75)" stroke="rgba(255, 0, 0, 0.25)" stroke-width="10"/>
# </svg>
# </g>

# %%
# %%d3
# <svg>
# <circle cx="25" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
# <circle cx="65" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.5"/>
# <circle cx="105" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.2"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select18 = function(selection) {
#     return _select("#d3-cell-18").select(selection);
# }
# d3.selectAll18 = function(selection) {
#     return _select("#d3-cell-18").selectAll(selection);
# }
# </script>
# <g id="d3-cell-18">
# <svg>
# <circle cx="25" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
# <circle cx="65" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.5"/>
# <circle cx="105" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.2"/>
# </svg>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25 ];
# w = 500
# h = 100
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# var circles = svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle");
#
# circles.attr("cx", function(d, i) {
#         return (i * 50) + 25;
#     })
#    .attr("cy", h/2)
#    .attr("r", function(d) {
#         return d;
#    });
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select19 = function(selection) {
#     return _select("#d3-cell-19").select(selection);
# }
# d3.selectAll19 = function(selection) {
#     return _select("#d3-cell-19").selectAll(selection);
# }
# </script>
# <g id="d3-cell-19">
#
# <svg />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25 ];
# w = 500
# h = 100
# var svg = d3.select19("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# var circles = svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle");
#
# circles.attr("cx", function(d, i) {
#         return (i * 50) + 25;
#     })
#    .attr("cy", h/2)
#    .attr("r", function(d) {
#         return d;
#    });
# </script>
# </g>

# %%
# %%d3
#
# <g></g>
#
# <script>
# var fruta = {
#     tipo: "uva",
#     color: "rojo",
#     cantidad: 12,
#     dulce: true
# };
# d3.select("g").append("p").text(JSON.stringify(fruta))
# d3.select("g").append("p").text(JSON.stringify(fruta))
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select20 = function(selection) {
#     return _select("#d3-cell-20").select(selection);
# }
# d3.selectAll20 = function(selection) {
#     return _select("#d3-cell-20").selectAll(selection);
# }
# </script>
# <g id="d3-cell-20">
#
# <g></g>
#
# <script>
# var fruta = {
#     tipo: "uva",
#     color: "rojo",
#     cantidad: 12,
#     dulce: true
# };
# d3.select20("g").append("p").text(JSON.stringify(fruta))
# d3.select20("g").append("p").text(JSON.stringify(fruta))
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*Math.min(w,h));
#     var y = Math.round(Math.random()*Math.min(w,h));
#     dataset.push([x, y]);
# }
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d) {
#         return d[0] + "," + d[1];
#     })
#     .attr("x", function(d) {
#         return d[0]+8;
#     })
#     .attr("y", function(d) {
#         return d[1]-8;
#     })
#     .attr("font-family", "sans-serif")
#     .attr("font-size", "11px")
#     .attr("fill", "red");
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select30 = function(selection) {
#     return _select("#d3-cell-30").select(selection);
# }
# d3.selectAll30 = function(selection) {
#     return _select("#d3-cell-30").selectAll(selection);
# }
# </script>
# <g id="d3-cell-30">
#
# <svg />
#
# <script>
#
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*Math.min(w,h));
#     var y = Math.round(Math.random()*Math.min(w,h));
#     dataset.push([x, y]);
# }
#
# var svg = d3.select30("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d) {
#         return d[0] + "," + d[1];
#     })
#     .attr("x", function(d) {
#         return d[0]+8;
#     })
#     .attr("y", function(d) {
#         return d[1]-8;
#     })
#     .attr("font-family", "sans-serif")
#     .attr("font-size", "11px")
#     .attr("fill", "red");
# </script>
# </g>

# %%
# %%d3
#
# <g />
#
# <script>
# var scale = d3.scale.linear()
#     .domain([100, 500])
#     .range([10, 350]);
#
# d3.select("g")
#     .append("p")
#     .text("100 -> "+ scale(100))
#     .append("p")
#     .text("200 -> "+scale(200))
#     .append("p")
#     .text("300 -> "+scale(300))
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select31 = function(selection) {
#     return _select("#d3-cell-31").select(selection);
# }
# d3.selectAll31 = function(selection) {
#     return _select("#d3-cell-31").selectAll(selection);
# }
# </script>
# <g id="d3-cell-31">
#
# <g />
#
# <script>
# var scale = d3.scale.linear()
#     .domain([100, 500])
#     .range([10, 350]);
#
# d3.select31("g")
#     .append("p")
#     .text("100 -> "+ scale(100))
#     .append("p")
#     .text("200 -> "+scale(200))
#     .append("p")
#     .text("300 -> "+scale(300))
#
# </script>
# </g>

# %%
# %%d3
#
# <h1>
# Not Scaled, uses Width and Height to create random values.
# Will usually not be the case, because we could use real data that has nothing to do with our W/H.
# </h1>
#
# <svg />
#
# <script>
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*w);
#     var y = Math.round(Math.random()*h);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, h]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([0, h]);
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select32 = function(selection) {
#     return _select("#d3-cell-32").select(selection);
# }
# d3.selectAll32 = function(selection) {
#     return _select("#d3-cell-32").selectAll(selection);
# }
# </script>
# <g id="d3-cell-32">
#
# <h1>
# Not Scaled, uses Width and Height to create random values.
# Will usually not be the case, because we could use real data that has nothing to do with our W/H.
# </h1>
#
# <svg />
#
# <script>
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*w);
#     var y = Math.round(Math.random()*h);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, h]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([0, h]);
#
# var svg = d3.select32("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# </script>
# </g>

# %%
# %%d3
# <h1>
# Not scaled
# </h1>
# <svg />
#
# <script>
# var w = 500;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*1000);
#     var y = Math.round(Math.random()*1000);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, w]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([0, h]);
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select33 = function(selection) {
#     return _select("#d3-cell-33").select(selection);
# }
# d3.selectAll33 = function(selection) {
#     return _select("#d3-cell-33").selectAll(selection);
# }
# </script>
# <g id="d3-cell-33">
# <h1>
# Not scaled
# </h1>
# <svg />
#
# <script>
# var w = 500;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*1000);
#     var y = Math.round(Math.random()*1000);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, w]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([0, h]);
#
# var svg = d3.select33("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# </script>
# </g>

# %%
# %%d3
# <h1>
# Scaled
# </h1>
# <svg />
#
# <script>
# var w = 500;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*1000);
#     var y = Math.round(Math.random()*1000);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, w]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([0, h]);
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return xScale(d[0]);
#     })
#     .attr("cy", function(d) {
#         return yScale(d[1]);
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select34 = function(selection) {
#     return _select("#d3-cell-34").select(selection);
# }
# d3.selectAll34 = function(selection) {
#     return _select("#d3-cell-34").selectAll(selection);
# }
# </script>
# <g id="d3-cell-34">
# <h1>
# Scaled
# </h1>
# <svg />
#
# <script>
# var w = 500;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*1000);
#     var y = Math.round(Math.random()*1000);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, w]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([0, h]);
#
# var svg = d3.select34("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return xScale(d[0]);
#     })
#     .attr("cy", function(d) {
#         return yScale(d[1]);
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# </script>
# </g>

# %%
# %%d3
# <h1>
# Scaled, inverted yScale. Begins from below. Should try with BarCharts.
# </h1>
# <svg />
#
# <script>
# var w = 1000;
# var h = 1000;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*500);
#     var y = Math.round(Math.random()*500);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, w]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([h, 0]);
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return xScale(d[0]);
#     })
#     .attr("cy", function(d) {
#         return yScale(d[1]);
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/2;
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select35 = function(selection) {
#     return _select("#d3-cell-35").select(selection);
# }
# d3.selectAll35 = function(selection) {
#     return _select("#d3-cell-35").selectAll(selection);
# }
# </script>
# <g id="d3-cell-35">
# <h1>
# Scaled, inverted yScale. Begins from below. Should try with BarCharts.
# </h1>
# <svg />
#
# <script>
# var w = 1000;
# var h = 1000;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*500);
#     var y = Math.round(Math.random()*500);
#     dataset.push([x, y]);
# }
#
# var xScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[0]; })])
#     .range([0, w]);
#
# var yScale = d3.scale.linear()
#     .domain([0, d3.max(dataset, function(d) {return d[1]; })])
#     .range([h, 0]);
#
# var svg = d3.select35("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return xScale(d[0]);
#     })
#     .attr("cy", function(d) {
#         return yScale(d[1]);
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/2;
#     });
#
# </script>
# </g>
