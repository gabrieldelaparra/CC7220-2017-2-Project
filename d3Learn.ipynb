# %%
import py_d3

# %%
# %reload_ext py_d3

# %%
# %%d3
#
# <g />
#
# <script>
# d3.select("g").text("Hello World");
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select0 = function(selection) {
#     return _select("#d3-cell-0").select(selection);
# }
# d3.selectAll0 = function(selection) {
#     return _select("#d3-cell-0").selectAll(selection);
# }
# </script>
# <g id="d3-cell-0">
#
# <g />
#
# <script>
# d3.select0("g").text("Hello World");
# </script>
# </g>

# %%
# %%d3
# <script type="text/javascript">
#     alert("Hello, world!");
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select1 = function(selection) {
#     return _select("#d3-cell-1").select(selection);
# }
# d3.selectAll1 = function(selection) {
#     return _select("#d3-cell-1").selectAll(selection);
# }
# </script>
# <g id="d3-cell-1">
# <script type="text/javascript">
#     alert("Hello, world!");
# </script>
# </g>

# %%
# %%d3
# <svg width="50" height="50">
#     <circle cx="25" cy="25" r="22"
#     fill="blue" stroke="gray" stroke-width="2"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select2 = function(selection) {
#     return _select("#d3-cell-2").select(selection);
# }
# d3.selectAll2 = function(selection) {
#     return _select("#d3-cell-2").selectAll(selection);
# }
# </script>
# <g id="d3-cell-2">
# <svg width="50" height="50">
#     <circle cx="25" cy="25" r="22"
#     fill="blue" stroke="gray" stroke-width="2"/>
# </svg>
# </g>

# %%
# %%d3
# <g></g>
#
# <script>
# d3.select("g")
#     .append("p")
#     .text("New paragraph!")
#     .append("p")
#     .text("New paragraph!");
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select3 = function(selection) {
#     return _select("#d3-cell-3").select(selection);
# }
# d3.selectAll3 = function(selection) {
#     return _select("#d3-cell-3").selectAll(selection);
# }
# </script>
# <g id="d3-cell-3">
# <g></g>
#
# <script>
# d3.select3("g")
#     .append("p")
#     .text("New paragraph!")
#     .append("p")
#     .text("New paragraph!");
# </script>
# </g>

# %%
# %%d3
# <g></g>
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25];
# d3.select("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("p")
#     .text("New paragraph!");
# console.log(d3.selectAll("p"));
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select4 = function(selection) {
#     return _select("#d3-cell-4").select(selection);
# }
# d3.selectAll4 = function(selection) {
#     return _select("#d3-cell-4").selectAll(selection);
# }
# </script>
# <g id="d3-cell-4">
# <g></g>
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25];
# d3.select4("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("p")
#     .text("New paragraph!");
# console.log(d3.selectAll4("p"));
# </script>
# </g>

# %%
# %%d3
# <g />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25];
# d3.select("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("p")
#     .text(function(d) { return "asd: " + d; });
# console.log(d3.selectAll("p"));
# alert("dataset[3]: " + dataset[3]);
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select5 = function(selection) {
#     return _select("#d3-cell-5").select(selection);
# }
# d3.selectAll5 = function(selection) {
#     return _select("#d3-cell-5").selectAll(selection);
# }
# </script>
# <g id="d3-cell-5">
# <g />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25];
# d3.select5("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("p")
#     .text(function(d) { return "asd: " + d; });
# console.log(d3.selectAll5("p"));
# alert("dataset[3]: " + dataset[3]);
# </script>
# </g>

# %%
# %%d3
#
# <g />
#
# <script>
# d3.select("g")
#     .text("Hello World")
#     .style("color","#ff00ff");
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select6 = function(selection) {
#     return _select("#d3-cell-6").select(selection);
# }
# d3.selectAll6 = function(selection) {
#     return _select("#d3-cell-6").selectAll(selection);
# }
# </script>
# <g id="d3-cell-6">
#
# <g />
#
# <script>
# d3.select6("g")
#     .text("Hello World")
#     .style("color","#ff00ff");
# </script>
# </g>

# %%
# %%d3
#
# <g />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25];
# d3.select("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("p")
#     .text(function(d) { return "asd: " + d; })
#     .style("color", function(d) {
#         if (d % 2 == 0) {
#             return "red";
#         } else {
#         return "blue";
#         }
#     });;
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select7 = function(selection) {
#     return _select("#d3-cell-7").select(selection);
# }
# d3.selectAll7 = function(selection) {
#     return _select("#d3-cell-7").selectAll(selection);
# }
# </script>
# <g id="d3-cell-7">
#
# <g />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25];
# d3.select7("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("p")
#     .text(function(d) { return "asd: " + d; })
#     .style("color", function(d) {
#         if (d % 2 == 0) {
#             return "red";
#         } else {
#         return "blue";
#         }
#     });;
# </script>
# </g>

# %%
# %%d3
#
# <g />
#
# <script>
# var dataset = "HelloWorld";
# var i = 0;
# d3.select("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("a")
#     .text(function(d) { return d + " "; })
#     .style("color", function(d) {
#         if (i % 2 == 0) {
#             i = i + 1;
#             return "red";
#         } else {
#             i = i + 1;
#             return "blue";
#         }
#     });;
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select8 = function(selection) {
#     return _select("#d3-cell-8").select(selection);
# }
# d3.selectAll8 = function(selection) {
#     return _select("#d3-cell-8").selectAll(selection);
# }
# </script>
# <g id="d3-cell-8">
#
# <g />
#
# <script>
# var dataset = "HelloWorld";
# var i = 0;
# d3.select8("g")
#     .selectAll("p")
#     .data(dataset)
#     .enter()
#     .append("a")
#     .text(function(d) { return d + " "; })
#     .style("color", function(d) {
#         if (i % 2 == 0) {
#             i = i + 1;
#             return "red";
#         } else {
#             i = i + 1;
#             return "blue";
#         }
#     });;
# </script>
# </g>

# %%
# %%d3
#
# <div style="display: inline-block;
#         width: 20px;
#         height: 75px;
#         background-color: teal;"></div>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select9 = function(selection) {
#     return _select("#d3-cell-9").select(selection);
# }
# d3.selectAll9 = function(selection) {
#     return _select("#d3-cell-9").selectAll(selection);
# }
# </script>
# <g id="d3-cell-9">
#
# <div style="display: inline-block;
#         width: 20px;
#         height: 75px;
#         background-color: teal;"></div>
# </g>

# %%
# %%d3
#
# <style>
# div.bar1 {
#     display: inline-block;
#     width: 20px;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
# }
# </style>
#
# <div class="bar1"></div>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select10 = function(selection) {
#     return _select("#d3-cell-10").select(selection);
# }
# d3.selectAll10 = function(selection) {
#     return _select("#d3-cell-10").selectAll(selection);
# }
# </script>
# <g id="d3-cell-10">
#
# <style>
# div.bar1 {
#     display: inline-block;
#     width: 20px;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
# }
# </style>
#
# <div class="bar1"></div>
# </g>

# %%
# %%d3
#
# <style>
# div.bar2 {
#     display: inline-block;
#     width: 20px;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
# }
# </style>
#
# <div />
#
# <script>
#     d3.select("div")
#         .attr("class", "bar2")
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select11 = function(selection) {
#     return _select("#d3-cell-11").select(selection);
# }
# d3.selectAll11 = function(selection) {
#     return _select("#d3-cell-11").selectAll(selection);
# }
# </script>
# <g id="d3-cell-11">
#
# <style>
# div.bar2 {
#     display: inline-block;
#     width: 20px;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
# }
# </style>
#
# <div />
#
# <script>
#     d3.select11("div")
#         .attr("class", "bar2")
# </script>
# </g>

# %%
# %%d3
#
# <style>
# div.bar3 {
#     display: inline-block;
#     width: 20px;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
#     margin-right: 2px;
# }
# </style>
#
# <g />
#
# <script>
#     var dataset = [ 25, 7, 5, 26, 11 ];
#     d3.select("g")
#         .selectAll("div")
#         .data(dataset)
#         .enter()
#         .append("div")
#         .attr("class", "bar3")
#         .style("height", function(d) {
#             return d*5+"px";})
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select12 = function(selection) {
#     return _select("#d3-cell-12").select(selection);
# }
# d3.selectAll12 = function(selection) {
#     return _select("#d3-cell-12").selectAll(selection);
# }
# </script>
# <g id="d3-cell-12">
#
# <style>
# div.bar3 {
#     display: inline-block;
#     width: 20px;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
#     margin-right: 2px;
# }
# </style>
#
# <g />
#
# <script>
#     var dataset = [ 25, 7, 5, 26, 11 ];
#     d3.select12("g")
#         .selectAll("div")
#         .data(dataset)
#         .enter()
#         .append("div")
#         .attr("class", "bar3")
#         .style("height", function(d) {
#             return d*5+"px";})
# </script>
# </g>

# %%
# %%d3
#
# <style>
# div.bar4 {
#     display: inline-block;
#     width: 1%;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
#     margin-right: 2px;
# }
# </style>
#
# <g />
#
# <script>
#     var dataset = [ ];
#
#      for (var i = 0; i < 70; i++) {
#          var newNumber = Math.round(Math.random() * 30);
#          dataset.push(newNumber);
#      }
#
#     console.log(dataset);
#
#     d3.select("g")
#         .selectAll("div")
#         .data(dataset)
#         .enter()
#         .append("div")
#         .attr("class", "bar4")
#         .style("height", function(d) {
#             return d*5+"px";})
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select13 = function(selection) {
#     return _select("#d3-cell-13").select(selection);
# }
# d3.selectAll13 = function(selection) {
#     return _select("#d3-cell-13").selectAll(selection);
# }
# </script>
# <g id="d3-cell-13">
#
# <style>
# div.bar4 {
#     display: inline-block;
#     width: 1%;
#     height: 75px;   /* Esto se cambiará próximamente */
#     background-color: teal;
#     margin-right: 2px;
# }
# </style>
#
# <g />
#
# <script>
#     var dataset = [ ];
#
#      for (var i = 0; i < 70; i++) {
#          var newNumber = Math.round(Math.random() * 30);
#          dataset.push(newNumber);
#      }
#
#     console.log(dataset);
#
#     d3.select13("g")
#         .selectAll("div")
#         .data(dataset)
#         .enter()
#         .append("div")
#         .attr("class", "bar4")
#         .style("height", function(d) {
#             return d*5+"px";})
# </script>
# </g>

# %%
# %%d3
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127
#         fill=red stroke=black stroke-width=4/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50
#         fill=blue stroke-width=4 stroke=black/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select14 = function(selection) {
#     return _select("#d3-cell-14").select(selection);
# }
# d3.selectAll14 = function(selection) {
#     return _select("#d3-cell-14").selectAll(selection);
# }
# </script>
# <g id="d3-cell-14">
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127
#         fill=red stroke=black stroke-width=4/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50
#         fill=blue stroke-width=4 stroke=black/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# </g>

# %%
# %%d3
# <style>
# svg .circle1 {
#     fill: red;
#     stroke: black;
#     stroke-width: 5;
# }
#
# svg .rect1 {
#     fill:blue;
#     stroke-width:4;
#     stroke:black;
# }
#
# </style>
#
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127 class="circle1"/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50 class="rect1"/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select15 = function(selection) {
#     return _select("#d3-cell-15").select(selection);
# }
# d3.selectAll15 = function(selection) {
#     return _select("#d3-cell-15").selectAll(selection);
# }
# </script>
# <g id="d3-cell-15">
# <style>
# svg .circle1 {
#     fill: red;
#     stroke: black;
#     stroke-width: 5;
# }
#
# svg .rect1 {
#     fill:blue;
#     stroke-width:4;
#     stroke:black;
# }
#
# </style>
#
# <svg width = 500 height =500>
#     <circle cx=200 cy=200 r=127 class="circle1"/>
#     <ellipse cx=250 cy=25 rx=100 ry=25/>
#     <rect x=0 y=400 width=500 height=50 class="rect1"/>
#     <line x1="" y1="300" x2="500" y2="50" stroke="purple"/>
#     <text x="250" y="25" font-family="sans-serif"
#         font-size="25" fill="gray">Easy-peasy</text>
# </svg>
# </g>

# %%
# %%d3
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 1.0)"/>
#     <circle cx="50" cy="25" r="20" fill="rgba(0, 0, 255, 0.75)"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.5)"/>
#     <circle cx="100" cy="25" r="20" fill="rgba(255, 255, 0, 0.25)"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 0, 0, 0.1)"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select16 = function(selection) {
#     return _select("#d3-cell-16").select(selection);
# }
# d3.selectAll16 = function(selection) {
#     return _select("#d3-cell-16").selectAll(selection);
# }
# </script>
# <g id="d3-cell-16">
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 1.0)"/>
#     <circle cx="50" cy="25" r="20" fill="rgba(0, 0, 255, 0.75)"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.5)"/>
#     <circle cx="100" cy="25" r="20" fill="rgba(255, 255, 0, 0.25)"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 0, 0, 0.1)"/>
# </svg>
# </g>

# %%
# %%d3
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 0.75)" stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.75)" stroke="rgba(0, 0, 255, 0.25)" stroke-width="10"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 255, 0, 0.75)" stroke="rgba(255, 0, 0, 0.25)" stroke-width="10"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select17 = function(selection) {
#     return _select("#d3-cell-17").select(selection);
# }
# d3.selectAll17 = function(selection) {
#     return _select("#d3-cell-17").selectAll(selection);
# }
# </script>
# <g id="d3-cell-17">
# <svg>
#     <circle cx="25" cy="25" r="20" fill="rgba(128, 0, 128, 0.75)" stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
#     <circle cx="75" cy="25" r="20" fill="rgba(0, 255, 0, 0.75)" stroke="rgba(0, 0, 255, 0.25)" stroke-width="10"/>
#     <circle cx="125" cy="25" r="20" fill="rgba(255, 255, 0, 0.75)" stroke="rgba(255, 0, 0, 0.25)" stroke-width="10"/>
# </svg>
# </g>

# %%
# %%d3
# <svg>
# <circle cx="25" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
# <circle cx="65" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.5"/>
# <circle cx="105" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.2"/>
# </svg>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select18 = function(selection) {
#     return _select("#d3-cell-18").select(selection);
# }
# d3.selectAll18 = function(selection) {
#     return _select("#d3-cell-18").selectAll(selection);
# }
# </script>
# <g id="d3-cell-18">
# <svg>
# <circle cx="25" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"/>
# <circle cx="65" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.5"/>
# <circle cx="105" cy="25" r="20"
#     fill="rgba(128, 0, 128, 0.75)"
#     stroke="rgba(0, 255, 0, 0.25)" stroke-width="10"
#     opacity="0.2"/>
# </svg>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25 ];
# w = 500
# h = 100
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# var circles = svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle");
#
# circles.attr("cx", function(d, i) {
#         return (i * 50) + 25;
#     })
#    .attr("cy", h/2)
#    .attr("r", function(d) {
#         return d;
#    });
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select19 = function(selection) {
#     return _select("#d3-cell-19").select(selection);
# }
# d3.selectAll19 = function(selection) {
#     return _select("#d3-cell-19").selectAll(selection);
# }
# </script>
# <g id="d3-cell-19">
#
# <svg />
#
# <script>
# var dataset = [ 5, 10, 15, 20, 25 ];
# w = 500
# h = 100
# var svg = d3.select19("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# var circles = svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle");
#
# circles.attr("cx", function(d, i) {
#         return (i * 50) + 25;
#     })
#    .attr("cy", h/2)
#    .attr("r", function(d) {
#         return d;
#    });
# </script>
# </g>

# %%
# %%d3
#
# <g></g>
#
# <script>
# var fruta = {
#     tipo: "uva",
#     color: "rojo",
#     cantidad: 12,
#     dulce: true
# };
# d3.select("g").append("p").text(JSON.stringify(fruta))
# d3.select("g").append("p").text(JSON.stringify(fruta))
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select20 = function(selection) {
#     return _select("#d3-cell-20").select(selection);
# }
# d3.selectAll20 = function(selection) {
#     return _select("#d3-cell-20").selectAll(selection);
# }
# </script>
# <g id="d3-cell-20">
#
# <g></g>
#
# <script>
# var fruta = {
#     tipo: "uva",
#     color: "rojo",
#     cantidad: 12,
#     dulce: true
# };
# d3.select20("g").append("p").text(JSON.stringify(fruta))
# d3.select20("g").append("p").text(JSON.stringify(fruta))
# </script>
# </g>

# %%
# %%d3
#
# <svg />
# <g /> </g>
#
# <style type="text/css">
#     div.bar5 {
#         vertical-align: middle;
#         display: inline-block;
#         width: 20px;
#         height: 75px;
#         margin-right: 2px;
#         background-color: teal;
#     }
#
# </style>
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21, 25, 22, 18, 15, 13,
#                     11, 12, 15, 20, 18, 17, 16, 18, 23, 25 ];
#
#     d3.select("g")
#         .selectAll("div")
#         .data(dataset)
#         .enter()
#         .append("div")
#         .attr("class", "bar5")
#         .style("height", function(d) {
#             var barHeight = d * 5;
#             return barHeight + "px";
#         });
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select35 = function(selection) {
#     return _select("#d3-cell-35").select(selection);
# }
# d3.selectAll35 = function(selection) {
#     return _select("#d3-cell-35").selectAll(selection);
# }
# </script>
# <g id="d3-cell-35">
#
# <svg />
# <g /> </g>
#
# <style type="text/css">
#     div.bar5 {
#         vertical-align: middle;
#         display: inline-block;
#         width: 20px;
#         height: 75px;
#         margin-right: 2px;
#         background-color: teal;
#     }
#
# </style>
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21, 25, 22, 18, 15, 13,
#                     11, 12, 15, 20, 18, 17, 16, 18, 23, 25 ];
#
#     d3.select35("g")
#         .selectAll("div")
#         .data(dataset)
#         .enter()
#         .append("div")
#         .attr("class", "bar5")
#         .style("height", function(d) {
#             var barHeight = d * 5;
#             return barHeight + "px";
#         });
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21, 25, 22, 18, 15, 13,
#                     11, 12, 15, 20, 18, 17, 16, 18, 23, 25 ];
# w = 500
# h = 100
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i*(w/dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", 20)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select27 = function(selection) {
#     return _select("#d3-cell-27").select(selection);
# }
# d3.selectAll27 = function(selection) {
#     return _select("#d3-cell-27").selectAll(selection);
# }
# </script>
# <g id="d3-cell-27">
#
# <svg />
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21, 25, 22, 18, 15, 13,
#                     11, 12, 15, 20, 18, 17, 16, 18, 23, 25 ];
# w = 500
# h = 100
# var svg = d3.select27("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i*(w/dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", 20)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     })
#     .style("width", "20px")
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21];
# w = 500
# h = 100
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i*(w/dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", 20)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select29 = function(selection) {
#     return _select("#d3-cell-29").select(selection);
# }
# d3.selectAll29 = function(selection) {
#     return _select("#d3-cell-29").selectAll(selection);
# }
# </script>
# <g id="d3-cell-29">
#
# <svg />
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21];
# w = 500
# h = 100
# var svg = d3.select29("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i*(w/dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", 20)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     })
#     .style("width", "20px")
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21];
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select36 = function(selection) {
#     return _select("#d3-cell-36").select(selection);
# }
# d3.selectAll36 = function(selection) {
#     return _select("#d3-cell-36").selectAll(selection);
# }
# </script>
# <g id="d3-cell-36">
#
# <svg />
#
# <script>
#     var dataset = [ 5, 10, 13, 19, 21];
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select36("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     });
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 70; i++){
#     dataset.push(Math.random()*20);
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select52 = function(selection) {
#     return _select("#d3-cell-52").select(selection);
# }
# d3.selectAll52 = function(selection) {
#     return _select("#d3-cell-52").selectAll(selection);
# }
# </script>
# <g id="d3-cell-52">
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 70; i++){
#     dataset.push(Math.random()*20);
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select52("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", 0)
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     });
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 70; i++){
#     dataset.push(Math.random()*100);
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     })
#     .attr("fill", "teal")
#     ;
#
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select59 = function(selection) {
#     return _select("#d3-cell-59").select(selection);
# }
# d3.selectAll59 = function(selection) {
#     return _select("#d3-cell-59").selectAll(selection);
# }
# </script>
# <g id="d3-cell-59">
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 70; i++){
#     dataset.push(Math.random()*100);
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select59("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return (d * 5) + "px";
#     })
#     .attr("fill", "teal")
#     ;
#
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 20; i++){
#     dataset.push(Math.round(Math.random()*100));
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("fill", function(d){
#         return "rgb(0,0,p)".replace("p",Math.round(d*(255/100)));
#     })
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return d;
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select179 = function(selection) {
#     return _select("#d3-cell-179").select(selection);
# }
# d3.selectAll179 = function(selection) {
#     return _select("#d3-cell-179").selectAll(selection);
# }
# </script>
# <g id="d3-cell-179">
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 20; i++){
#     dataset.push(Math.round(Math.random()*100));
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select179("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("fill", function(d){
#         return "rgb(0,0,p)".replace("p",Math.round(d*(255/100)));
#     })
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return d;
#     });
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 20; i++){
#     dataset.push(Math.round(Math.random()*100));
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("fill", function(d){
#         return "rgb(0,0,p)".replace("p",Math.round(d*(255/100)));
#     })
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return d;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d){
#         return d;
#     })
#     .attr("x", function(d,i){
#         return i*(w/dataset.length)+2;
#     })
#     .attr("y", function(d){
#         return h-d-1;
#     });
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select192 = function(selection) {
#     return _select("#d3-cell-192").select(selection);
# }
# d3.selectAll192 = function(selection) {
#     return _select("#d3-cell-192").selectAll(selection);
# }
# </script>
# <g id="d3-cell-192">
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 20; i++){
#     dataset.push(Math.round(Math.random()*100));
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select192("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("fill", function(d){
#         return "rgb(0,0,p)".replace("p",Math.round(d*(255/100)));
#     })
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return d;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d){
#         return d;
#     })
#     .attr("x", function(d,i){
#         return i*(w/dataset.length)+2;
#     })
#     .attr("y", function(d){
#         return h-d-1;
#     });
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 10; i++){
#     dataset.push(Math.round(Math.random()*100));
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("fill", function(d){
#         return "rgb(0,0,p)".replace("p",Math.round(d*(255/100)));
#     })
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return d;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d){
#         return d;
#     })
#     .attr("x", function(d,i){
#         return i * (w / dataset.length) + (w / dataset.length - barPadding) / 2;
#     })
#     .attr("y", function(d){
#         return h-d+15;
#     })
#     .attr("font-family", "sans-serif")
#     .attr("font-size", "11px")
#     .attr("fill", "white")
#     .attr("text-anchor", "middle");
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select203 = function(selection) {
#     return _select("#d3-cell-203").select(selection);
# }
# d3.selectAll203 = function(selection) {
#     return _select("#d3-cell-203").selectAll(selection);
# }
# </script>
# <g id="d3-cell-203">
#
# <svg />
#
# <script>
#
# var dataset = [];
# for(var i = 0; i < 10; i++){
#     dataset.push(Math.round(Math.random()*100));
#
# }
#
# var w = 500;
# var h = 100;
# var barPadding = 1;
#
# var svg = d3.select203("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("rect")
#     .data(dataset)
#     .enter()
#     .append("rect")
#     .attr("fill", function(d){
#         return "rgb(0,0,p)".replace("p",Math.round(d*(255/100)));
#     })
#     .attr("x", function(d, i) {
#         return i * (w / dataset.length);
#     })
#     .attr("y", function(d){
#         return h-d;
#     })
#     .attr("width", w / dataset.length - barPadding)
#     .attr("height", function(d) {
#         return d;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d){
#         return d;
#     })
#     .attr("x", function(d,i){
#         return i * (w / dataset.length) + (w / dataset.length - barPadding) / 2;
#     })
#     .attr("y", function(d){
#         return h-d+15;
#     })
#     .attr("font-family", "sans-serif")
#     .attr("font-size", "11px")
#     .attr("fill", "white")
#     .attr("text-anchor", "middle");
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
#
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*Math.min(w,h));
#     var y = Math.round(Math.random()*Math.min(w,h));
#     dataset.push([x, y]);
# }
#
# var svg = d3.select("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d) {
#         return d[0] + "," + d[1];
#     })
#     .attr("x", function(d) {
#         return d[0]+8;
#     })
#     .attr("y", function(d) {
#         return d[1]-8;
#     })
#     .attr("font-family", "sans-serif")
#     .attr("font-size", "11px")
#     .attr("fill", "red");
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select234 = function(selection) {
#     return _select("#d3-cell-234").select(selection);
# }
# d3.selectAll234 = function(selection) {
#     return _select("#d3-cell-234").selectAll(selection);
# }
# </script>
# <g id="d3-cell-234">
#
# <svg />
#
# <script>
#
#
#
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*Math.min(w,h));
#     var y = Math.round(Math.random()*Math.min(w,h));
#     dataset.push([x, y]);
# }
#
# var svg = d3.select234("svg")
#     .attr("width", w)
#     .attr("height", h);
#
# svg.selectAll("circle")
#     .data(dataset)
#     .enter()
#     .append("circle")
#     .attr("cx", function(d) {
#         return d[0];
#     })
#     .attr("cy", function(d) {
#         return d[1];
#     })
#     .attr("r", function(d) {
#         return Math.sqrt(h - d[1])/1.7;
#     });
#
# svg.selectAll("text")
#     .data(dataset)
#     .enter()
#     .append("text")
#     .text(function(d) {
#         return d[0] + "," + d[1];
#     })
#     .attr("x", function(d) {
#         return d[0]+8;
#     })
#     .attr("y", function(d) {
#         return d[1]-8;
#     })
#     .attr("font-family", "sans-serif")
#     .attr("font-size", "11px")
#     .attr("fill", "red");
# </script>
# </g>

# %%
# %%d3
#
# <g />
# <svg />
#
# <script>
# var scale = d3.scale.linear()
#     .domain([100, 500])
#     .range([10, 350]);
#
# d3.select("g")
#     .
#
# </script>
# Out:
# <script>
# requirejs.config({
#     paths: {
#         d3: "//cdnjs.cloudflare.com/ajax/libs/d3/3.5.17/d3"
#     }
# });
#
# require(['d3'], function(d3) {
#     window.d3 = d3;
# });
# </script>
# <script>
# _select = d3.select;
#
# d3.select235 = function(selection) {
#     return _select("#d3-cell-235").select(selection);
# }
# d3.selectAll235 = function(selection) {
#     return _select("#d3-cell-235").selectAll(selection);
# }
# </script>
# <g id="d3-cell-235">
#
# <svg />
#
# <script>
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*Math.min(w,h));
#     var y = Math.round(Math.random()*Math.min(w,h));
#     dataset.push([x, y]);
# }
#
# var scale = d3.scale.linear()
#     .domain([100, 500])
#     .range([10, 350]);
#
# </script>
# </g>

# %%
# %%d3
#
# <svg />
#
# <script>
# var w = 1000;
# var h = 500;
# var barPadding = 1;
#
# var dataset = [];
# for(var i = 0; i < 100; i++){
#     var x = Math.round(Math.random()*Math.min(w,h));
#     var y = Math.round(Math.random()*Math.min(w,h));
#     dataset.push([x, y]);
# }
#
# var scale = d3.scale.linear()
#     .domain([100, 500])
#     .range([10, 350]);
#
# </script>
